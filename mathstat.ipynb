# %%
import math
import numpy as np
import random
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import studentized_range
from pylab import rcParams
import matplotlib.animation as animation
import os
from PIL import Image
from IPython.display import Image
import pandas as pd
import plotly.io as pio
from datetime import datetime, timezone

pio.renderers.default='notebook'
sns.set()
rcParams['figure.figsize'] = 10, 6
#%matplotlib notebook
# %config InlineBackend.figure_format = 'svg'

# %%
a = "1 3 1 3 7 8 9 10 12 12 13 18 20 19"

# %%
b = '2 6 2 6 14 16 18 20 24 24 26 36 40 38'

# %%
def function2(x):
    return x.split()

# %%
def function1(x):
    for j, i in enumerate(x):
        i = int(i)
        x[j] = i
    return x

# %%
temp_list = function2(a)

# %%
selection_1 = function1(temp_list)

# %%
temp_list_2 = function2(b)

# %%
selection_2 = function1(temp_list_2)

# %%
np.mean(selection_1)
# Out:
# 9.714285714285714

# %%
np.mean(selection_2)
# Out:
# 19.428571428571427

# %% [markdown]
# # Меры изменчивости

# %% [markdown]
# ## sdfsd

# %%
random_list = []
for i in range(0,100):
    random_list.append((i * 0 + random.randint(0,10)))

# %%
data = np.random.randn(1000)

# %%
data
# Out:
# array([-1.90208789e+00, -6.28963935e-01,  1.60286978e-01, -7.02556382e-01,
#        -9.59901149e-02,  2.02889163e+00, -9.91082998e-01,  1.02944381e+00,
#         3.59686411e-01, -7.67746523e-01, -1.85352141e+00, -6.51497491e-01,
#        -1.43048676e+00, -2.17356306e+00, -6.37843392e-01,  3.61444976e-01,
#        -1.01533976e+00, -1.03177602e+00, -4.33850045e-01,  1.16269803e+00,
#        -1.45456318e+00, -2.54607816e+00, -4.59652699e-01, -1.16576442e+00,
#         8.79147235e-01, -4.31566250e-01,  2.74628553e-01,  1.16590212e+00,
#         1.10126109e-02,  1.08717848e+00, -1.35462504e+00,  1.31254131e+00,
#        -1.09577337e+00, -1.39875221e+00, -1.61920878e+00, -1.75691423e+00,
#        -1.57517064e-01, -4.90353086e-01,  2.68467395e-01,  7.33449872e-01,
#        -1.18767882e-01, -1.33330614e-01, -2.52853298e+00,  1.72626506e+00,
#        -8.01865784e-01,  1.15704136e+00,  5.82174305e-01, -3.93923200e-01,
#        -5.98748666e-01, -8.16414416e-01,  5.08036646e-01,  8.83165083e-01,
#        -5.20076068e-01,  2.85379745e+00,  1.05466695e+00, -9.22798830e-01,
#         1.30609540e+00, -3.10872231e-01, -1.75638556e+00,  8.97120294e-01,
#         1.44842047e+00,  2.28464337e+00, -6.10601114e-01, -1.87961045e+00,
#        -2.01875439e+00, -6.38779187e-01,  4.84083038e-01,  8.91455043e-01,
#         4.83141920e-02, -1.62051292e+00,  1.27270108e+00, -3.09942462e-01,
#        -4.13286232e-01,  1.28883572e+00,  5.46521143e-01,  1.29786380e+00,
#        -4.25973491e-01, -5.80414057e-01, -1.02256381e-01, -6.40491870e-01,
#         6.38180292e-01,  1.51318216e-01,  6.27848432e-01,  3.11830246e-01,
#        -8.87962596e-01, -1.99956495e+00, -1.12918542e+00, -7.41025649e-01,
#         5.95652588e-01,  9.76461212e-01,  1.81304268e+00, -1.26242295e+00,
#        -5.73773380e-02, -1.33716423e+00, -1.12492202e+00, -1.03545218e+00,
#         3.13244254e-01, -2.85232760e-01,  4.28924515e-01,  1.51968357e+00,
#        -4.99478741e-01, -8.35899854e-01,  1.72855895e+00,  6.89088572e-01,
#        -3.70106736e-01, -3.46844690e-02, -1.41409102e-01, -9.20708020e-01,
#         2.43887084e-01,  7.57286106e-01,  7.94843636e-01,  1.43429385e+00,
#        -3.63448037e-01,  3.43323495e-01,  7.89578789e-01,  3.23546195e+00,
#         4.72648053e-02, -6.92484726e-01,  1.80028116e+00, -3.22470320e-01,
#         1.12599255e+00, -4.09793459e-01,  1.52529341e-01, -7.81648935e-02,
#        -5.39824283e-01,  3.99464555e-02, -3.43410897e-01,  4.20304160e-01,
#         4.46375946e-01,  2.10389902e-01, -7.54768012e-01, -7.10286708e-01,
#        -8.78960844e-01,  2.08884350e+00,  6.80524522e-01,  3.47607846e-01,
#         9.26959408e-01, -1.71084162e-01, -1.04813854e+00,  1.17886947e+00,
#         1.87007584e+00,  4.41420282e-01, -3.40411228e-01, -2.49373438e-01,
#        -4.12296882e-01,  5.02480040e-01, -7.24424620e-01, -3.08660229e-01,
#        -8.47174248e-01,  1.50202672e-01, -5.25215474e-01,  5.19303316e-01,
#         6.27607210e-01,  4.43827034e-01, -4.48064563e-01,  1.08847307e+00,
#         2.07503984e+00, -1.04070810e+00,  1.62221247e+00, -1.66723592e+00,
#        -9.15962696e-01,  4.07705242e-01,  1.29294180e-01, -4.37902156e-01,
#         1.14701765e+00, -4.29368525e-01, -5.91685337e-01,  6.50790312e-01,
#        -5.39278962e-01,  2.58031699e+00,  1.02428346e+00,  9.22843381e-01,
#        -1.29681415e+00,  6.17249281e-01, -2.00189437e-01,  6.92517827e-01,
#         9.68159816e-01, -2.52308918e-01, -3.55627267e-01,  1.15777944e+00,
#         1.25381734e+00, -9.18557706e-01, -2.92368707e-01, -5.60855606e-01,
#        -2.90239760e-01, -9.47764493e-01, -2.82512305e-01, -8.41736761e-01,
#        -5.09728051e-01, -9.04954679e-01, -1.89411542e-01, -1.19414806e+00,
#        -1.56623089e+00, -6.47477127e-01, -8.88396609e-01,  1.51411154e+00,
#         2.74280609e-01, -1.03097428e+00,  4.63416617e-01, -1.13692624e+00,
#         5.15615268e-01, -1.78295709e+00, -2.20324674e-02,  1.04745556e+00,
#         2.63388083e-02,  5.03148849e-01, -2.22126355e+00,  2.33315396e-01,
#         3.77586454e-01, -8.62026034e-01,  1.32105992e+00, -1.09429613e+00,
#        -7.72999193e-03,  3.24384748e-01, -1.07266503e+00, -2.37959683e-01,
#         4.26472478e-01,  6.70699423e-01,  2.02920598e-01, -4.10857105e-01,
#        -1.93744012e+00, -6.48043472e-01,  4.76462285e-01,  5.49480959e-01,
#         2.97769236e-01,  2.01302641e+00, -5.30890702e-01,  1.83268536e+00,
#         1.43690122e+00, -8.07635265e-01,  2.79537690e-01,  3.72423989e-02,
#        -1.58344823e+00,  1.09772446e+00,  1.39834463e+00,  1.25068749e+00,
#        -1.10612266e+00, -3.00519889e-01, -1.09455574e+00,  1.10141960e-01,
#         3.43861739e-01, -1.08399059e+00,  2.96651328e+00,  2.28939626e+00,
#         5.57923832e-01, -2.58298811e+00,  6.01130470e-01, -5.86814727e-02,
#         1.64322984e-01, -2.32821071e-01,  7.18004341e-01,  2.72503026e-01,
#         6.44586802e-01,  3.78651081e-01, -2.86765182e-01,  1.45118341e+00,
#         7.05139005e-01, -6.36264148e-01, -1.43562707e+00, -3.40764434e-01,
#         5.59505407e-01, -5.50535457e-01, -5.77294151e-01,  6.34354379e-01,
#        -1.64908678e+00,  1.62410454e+00, -6.40406852e-01, -5.43717785e-01,
#        -3.87245441e-01, -2.54668731e-01, -8.46612433e-01, -9.07128604e-01,
#        -4.80020835e-01,  8.44536471e-01,  4.56645452e-01, -1.27516835e+00,
#         4.80614108e-01,  6.92752595e-01, -2.52902713e-01, -1.20490808e+00,
#         1.14037998e+00, -5.84181164e-01, -3.36588027e-01,  4.09751496e-02,
#         1.08983738e-01,  1.16496062e-01,  1.24794395e+00, -3.81198900e-02,
#         1.47467805e+00,  6.73424667e-01,  5.47543719e-01,  4.43342619e-01,
#        -5.89479956e-01, -2.40519969e+00,  6.69989853e-01, -6.88813537e-01,
#        -1.32139181e+00,  5.14236896e-01, -1.17123824e+00,  4.12511136e-01,
#         3.72097245e-01,  8.40869823e-01, -1.06405320e+00, -1.04836521e-01,
#         3.31751820e-02, -2.26880297e-01, -3.86029643e-01, -6.14656057e-01,
#        -8.83623569e-01, -1.14157787e+00,  2.95383047e-01, -2.41289552e-01,
#         1.91253331e-01,  1.78950340e+00,  7.63126413e-01, -5.19498199e-01,
#         2.75069256e-01,  6.02194717e-01, -3.13736033e-01,  6.19761984e-01,
#         8.82613065e-01,  1.05295677e+00,  1.44892984e-01, -4.38508248e-01,
#        -8.36705119e-02, -2.17657331e+00,  5.42518057e-01, -2.42227513e+00,
#         6.74661994e-01, -6.03286622e-02,  1.86333235e-01,  6.68736493e-01,
#         1.88462020e+00, -2.14279361e+00, -6.34828057e-01,  6.61660530e-01,
#        -1.10522993e+00, -8.01243907e-01, -4.96246530e-01,  1.72182313e+00,
#        -1.44810820e+00,  1.02540728e+00,  9.36269247e-01,  4.09776894e-01,
#        -1.08412076e+00, -6.59160158e-02, -4.50517006e-01,  5.21414301e-01,
#        -1.37375955e+00, -1.31499030e+00, -2.91155234e-01, -1.42643960e+00,
#        -5.94847843e-01,  2.36291732e-01,  1.17130333e+00, -5.20977240e-01,
#         1.21169848e-01,  7.24803018e-02,  5.79640084e-01, -1.49849110e+00,
#        -4.49913051e-01,  1.66946219e+00, -3.82516136e-01,  8.13925376e-01,
#        -9.12943195e-01,  1.03221811e+00,  3.75051764e-01,  4.47684120e-03,
#        -6.61948003e-01,  4.51884441e-01,  5.42068084e-01,  3.33811351e-01,
#         4.17711326e-01, -5.46783954e-01, -6.36041839e-01, -2.91582850e-01,
#        -7.40628550e-01,  7.04520187e-01,  1.65067529e+00,  1.43649873e+00,
#         8.39758196e-01, -7.13631090e-01, -4.73921166e-01, -1.94155010e-01,
#         7.36000108e-01,  1.23064181e+00,  1.11588796e+00, -1.44698528e-01,
#         3.86517769e-01, -1.04388435e+00, -4.61668235e-01,  1.90440693e+00,
#        -4.80300222e-01,  5.51624435e-01, -6.07140618e-01, -1.26419698e+00,
#        -1.28405403e+00,  2.80820280e-01, -3.20289279e-01, -1.31538268e+00,
#         2.15531423e+00, -1.02537305e+00,  9.32079065e-01,  1.28592289e+00,
#        -7.70542169e-01, -1.95984585e+00, -1.46129719e+00,  2.20294290e-01,
#        -2.42049263e-01,  1.47675832e+00,  5.54527306e-02,  8.80610479e-01,
#         8.01351655e-01, -1.95950740e-01, -8.35920779e-01,  2.46680924e-02,
#        -5.06168123e-01,  1.28707224e+00, -1.74942532e-01, -4.14002009e-01,
#         4.86529032e-01, -1.45472503e+00, -8.87894764e-02,  1.59665131e+00,
#         2.92986547e-02,  5.11450173e-02, -4.25093734e-02,  4.01575482e-01,
#        -1.05531998e+00,  5.11909557e-01, -6.12223860e-01, -6.51338770e-03,
#        -8.51092328e-01,  1.71387145e-01,  8.79873434e-01,  1.25694420e-01,
#        -5.50091447e-03, -2.78785040e+00,  1.10865007e+00, -1.73102284e+00,
#        -4.81177812e-01, -1.58099952e-01, -1.50973358e+00,  3.18773227e-01,
#         8.96052478e-01,  1.31514824e+00,  6.68825941e-01,  1.85149747e-01,
#        -5.89986016e-01,  1.71692229e+00, -1.13281705e+00,  1.04360534e+00,
#        -1.89183349e+00, -1.23334026e+00, -7.51596411e-01,  4.52318739e-01,
#        -6.62260671e-01, -6.97861779e-01,  2.77734240e+00, -3.24752793e-01,
#        -5.61718351e-01, -1.35434931e+00, -2.72662438e+00,  3.59439777e-01,
#        -4.54190437e-01, -1.23880165e-01, -3.33139007e-02,  8.03888021e-01,
#         6.76276374e-01, -1.17476653e+00,  1.73217379e+00,  2.77955692e-01,
#         1.29828497e+00, -1.48439006e+00, -5.59212791e-01, -2.07906167e-01,
#         1.09420909e+00, -3.88633620e-01,  1.77953645e+00,  1.37658486e+00,
#        -2.35032126e+00,  3.14538538e-01, -5.30810276e-01, -1.47089607e-01,
#         1.29103534e+00, -4.14254799e-03,  7.42921228e-01, -1.47115676e+00,
#         4.95963352e-01, -1.13351285e+00, -1.95010505e-01, -7.70722064e-01,
#         1.75274982e+00, -6.56821102e-01, -9.96574814e-01, -1.02985263e+00,
#         5.23972725e-01, -4.67475007e-01,  8.64558380e-01, -3.97491733e-01,
#        -1.46742612e-01, -1.17497997e+00, -5.61013880e-01,  5.34723646e-01,
#        -1.25528780e+00, -1.52447280e-02,  4.06863285e-02, -9.51512358e-01,
#        -8.35257525e-01, -1.11716072e+00,  9.46572097e-02,  2.30413922e-01,
#        -3.61157299e-01,  4.52189206e-01,  1.52480625e-01, -7.08288834e-01,
#         5.24142061e-01, -9.68106086e-01, -1.14540076e-01,  2.87690273e-01,
#         1.02457181e+00, -7.03622644e-01,  9.71129714e-01,  7.31198824e-01,
#         1.66147625e+00, -1.92031489e+00,  3.98773920e-01,  1.53145737e+00,
#         1.05984083e+00, -4.64847180e-01,  1.33817534e+00, -1.16431286e+00,
#        -1.25510409e+00,  1.24778676e+00, -2.95782581e-01,  1.01807292e+00,
#         3.44939097e-01, -3.39945312e-01, -2.18753306e+00, -8.36441462e-01,
#         5.10095841e-01,  7.82701657e-01,  4.02317271e-01,  3.03936415e-01,
#         1.05785812e+00, -8.47695579e-01, -1.74991985e+00, -8.18414031e-01,
#         2.19620927e+00, -1.05233793e+00,  3.10190005e-01,  1.86461324e+00,
#         4.50084385e-01,  1.85323849e-01,  1.18794766e+00, -1.33303130e+00,
#        -1.08680251e+00, -1.54507584e+00, -1.64795558e+00, -6.36057601e-01,
#         2.20574687e+00,  5.46504203e-02,  4.61037639e-01, -1.79101917e-01,
#        -1.37220669e+00, -9.83705455e-02,  5.14283563e-01, -3.54324575e-01,
#         1.12418563e+00,  1.33061336e-01, -4.01501358e-01, -1.16868488e+00,
#         1.02135172e+00,  1.68553568e-01, -4.17573621e-02,  1.95049580e+00,
#        -2.55276358e-01,  1.07854268e+00,  3.01900072e-01,  4.54950522e-02,
#        -1.15314325e+00,  2.31999539e-01,  2.35545872e-01, -1.74948180e+00,
#        -2.98674262e-01, -1.20255856e+00,  2.40962174e-01, -1.27164694e-01,
#        -4.57794006e-01,  4.97303430e-01, -6.90692268e-01, -1.48926315e+00,
#         2.99561831e-01, -1.72136819e+00,  1.21099244e+00, -3.64287751e-01,
#        -2.04811417e+00,  3.50066457e-01,  4.94454130e-01, -3.19255375e-01,
#        -1.74137899e+00,  1.88201778e-01,  1.19600927e+00, -5.93827153e-01,
#         4.37188287e-01,  7.05027466e-01,  7.96064777e-01, -4.25185331e-01,
#         5.73801399e-01, -4.05146160e-01,  3.33053036e-01,  2.88670219e-01,
#         2.39079295e-01, -6.58218395e-03,  8.64285144e-01, -7.54177816e-01,
#        -5.42992476e-02, -2.95600844e+00,  4.71820543e-01, -6.24892195e-01,
#        -2.02302971e-01,  2.85218516e+00,  1.30766023e+00, -6.34709829e-01,
#        -1.27870677e+00,  2.22470136e+00, -3.81638510e-01,  4.57465019e-01,
#         1.22879291e+00, -9.61497653e-01,  1.01977338e+00,  7.81893941e-01,
#         4.22721917e-01,  4.36801345e-01, -1.23168432e+00,  6.84278817e-01,
#        -2.75381821e-01,  8.97991795e-01, -5.51331767e-01,  1.18847558e+00,
#        -4.09408443e-01, -9.80828889e-01,  7.78154308e-01, -4.57782238e-01,
#        -7.31458003e-01, -1.83747397e+00, -2.24390091e-01,  1.81495908e-01,
#         1.83938950e+00, -3.59005599e-01, -1.86555826e-01,  6.80666610e-01,
#        -1.55153238e+00,  1.07157650e+00, -2.22467352e-01, -2.53851936e+00,
#         1.14215593e+00, -1.78266149e+00,  1.64027628e-01, -9.03961706e-01,
#         1.32637846e+00,  1.20561042e-02, -9.19719399e-01,  1.79404635e+00,
#        -1.51170773e+00, -5.55416600e-01, -2.87635153e-01, -1.91937396e+00,
#        -5.78669587e-01,  1.33140004e+00, -6.06974105e-01, -8.26875692e-01,
#         7.62918078e-01,  6.35652463e-03, -2.35638560e+00, -7.41429174e-01,
#         1.01589170e+00,  1.00856312e+00, -1.80866469e+00,  5.60420850e-01,
#        -2.41959542e-01, -7.23326304e-01, -6.42365338e-01, -6.88112080e-01,
#        -1.38184220e+00, -3.98249747e-01, -3.78031587e-01,  1.64110540e-01,
#        -8.68587096e-01,  9.15543319e-01, -1.34727322e+00,  1.59453866e+00,
#        -2.46854504e-01,  7.21318746e-01, -1.06876659e+00, -5.49566211e-01,
#         7.68774381e-01,  1.74954958e+00,  6.42529292e-01,  1.26457351e+00,
#         2.22635725e-01,  1.50380583e+00,  7.02888674e-01, -1.85507965e-01,
#         1.69368290e-01,  1.41743121e+00, -5.50279583e-01, -3.26006132e-01,
#        -2.06354393e+00,  6.55301135e-01,  1.57748460e+00, -1.04028128e+00,
#        -1.24983415e-01, -1.12538207e+00, -7.87270713e-01,  1.70411190e-01,
#         1.47548449e+00,  6.10014590e-01, -1.39765432e+00, -1.30838976e+00,
#        -1.72812221e-01,  1.22568380e+00, -1.03616563e+00,  7.31951662e-01,
#         4.36200006e-01, -5.85146918e-02, -6.64030637e-01,  2.66141433e-01,
#        -1.30257207e+00,  8.46785948e-01, -8.25236866e-02, -3.25232706e-01,
#        -4.81750738e-01,  1.38421506e+00,  1.26965966e+00,  2.07681374e+00,
#        -5.14400004e-01, -9.79124329e-01, -5.96626201e-01,  5.18481853e-01,
#        -4.49845346e-01, -4.22258133e-01,  7.09865048e-01,  2.81160718e-01,
#         9.14537757e-01, -1.52314499e+00, -3.26325701e-01,  2.63528447e-01,
#        -8.46217560e-01,  8.09799037e-01,  6.54403804e-01,  7.24505578e-01,
#         1.17099395e-01,  1.04858122e+00, -7.10854609e-01,  4.48584875e-02,
#        -4.30063427e-01,  6.22846274e-01, -3.65277768e-01,  2.11088641e-01,
#        -3.97599157e-02,  1.03834810e-01,  2.37482486e-01, -1.70646790e-01,
#        -1.13617216e+00, -1.11991589e+00, -9.34022543e-01,  1.19599745e-01,
#        -2.29698710e-01,  1.11269607e+00, -1.12786598e-01, -3.80768565e-01,
#         1.33627498e+00, -1.65823288e+00,  1.86130754e-01,  7.14814117e-01,
#        -2.48225991e-01,  7.58294360e-01, -1.12734118e+00, -1.56224658e+00,
#        -1.66877408e-01, -8.02691640e-01,  9.02170336e-01, -1.55908051e+00,
#         3.41233822e-02, -1.16410392e+00,  1.27812752e+00,  4.16084705e-02,
#         1.78185130e-01,  4.13904324e-01,  9.93326043e-02,  1.01390251e+00,
#        -2.35555141e+00,  4.49950025e-02, -5.81243636e-01,  1.30207887e+00,
#        -6.01185783e-01,  1.52659355e-02,  1.76699502e+00, -1.17607329e+00,
#         1.13454318e+00,  1.53849402e+00, -3.04695832e-01, -2.57775091e-01,
#         1.74542130e+00, -1.61124226e+00, -2.97552139e-01, -5.49956929e-01,
#         8.79062638e-02,  3.47024753e-02,  9.77454408e-01, -1.37757400e+00,
#        -1.16921899e+00,  1.30498664e+00,  1.51804298e+00,  1.11850338e+00,
#         7.03771661e-01, -4.20421872e-01,  2.49600353e-01,  1.12790581e+00,
#        -2.74694244e-01,  1.33219437e+00,  1.37876537e+00, -2.94702384e-01,
#         2.39409742e-01,  9.09272251e-01, -1.51902225e+00,  3.81035121e-01,
#        -1.75931653e+00,  9.33851133e-02,  1.14321442e+00,  1.81149318e+00,
#         1.82784586e+00,  4.42030148e-01, -3.69286318e-01, -2.10468194e+00,
#        -1.81444076e+00,  1.92067835e+00, -1.58856041e-03,  1.27504504e+00,
#         1.17559398e+00, -2.21251200e-01,  3.95628996e-02,  1.60166862e+00,
#         2.00611948e+00, -2.98634186e+00,  2.78784485e-01,  1.63313273e+00,
#        -4.03127232e-01, -2.24142596e-01, -4.07033087e-01,  1.76604920e-01,
#         1.12071851e+00,  7.86470590e-01, -3.47750782e-01, -1.90795088e+00,
#         8.89143624e-01,  1.27898821e-01,  2.45680138e-02, -1.26656182e+00,
#         5.88575293e-01, -1.06771600e+00,  2.28687391e+00, -4.10245945e-01,
#         2.13686007e-01, -4.08414851e-01,  2.54135993e-01,  9.52998987e-01,
#        -4.34067594e-01, -7.21000675e-01, -5.14350805e-01,  1.86171864e-01,
#        -5.83785485e-01,  1.46111579e+00,  1.16015638e+00, -4.15723795e-01,
#        -1.79927975e-03, -1.14426223e+00,  3.96550478e-01,  2.27087523e+00,
#        -1.22329504e+00, -1.61184210e-01, -4.66728588e-02, -1.07440392e+00,
#         2.55840265e+00,  7.46906877e-01, -1.58993115e-01, -5.72150491e-01,
#         3.44340532e-01,  2.42652235e-01,  8.55476152e-01,  1.30466972e-01,
#         8.62409672e-01, -5.30318675e-01, -6.04787817e-01, -2.17374691e+00,
#         1.50451104e+00, -6.80781493e-01,  3.65492974e-01, -1.06367055e-01,
#         3.53258579e-01, -3.80316395e-01, -1.40887451e+00,  1.75135253e+00,
#        -1.11371388e+00,  8.87316453e-01, -4.04310375e-01,  2.92415525e-01,
#         1.17001866e+00,  1.12918647e-01, -6.39199449e-01, -1.05935554e-01,
#        -1.64881654e-01, -1.15549135e+00, -7.16058851e-01,  3.80536511e-01,
#         2.29758170e+00, -4.67438038e-01, -1.78565008e+00, -4.50310540e-01,
#        -3.57826242e-01,  6.16595555e-01, -1.83307730e-01, -2.87260757e-01,
#        -1.43163876e-01, -2.54357781e+00,  1.28625975e-02, -1.23469278e+00,
#        -1.16876018e+00, -7.49673689e-01, -9.04573396e-01, -2.83369474e+00,
#         1.64973517e+00, -2.58363369e-01, -1.39998120e+00,  7.57407465e-02,
#         1.59279054e+00, -1.04542825e-01, -2.78869722e+00,  3.89583255e-01,
#        -1.10192832e+00, -9.36893103e-01, -2.50200081e+00, -1.78948874e+00,
#         1.31996498e+00, -1.37026656e+00,  7.66350967e-01,  8.25015844e-01,
#         9.02313643e-01, -3.69797582e-02, -3.70630409e-01,  3.34451249e-01,
#         3.14695814e-01, -1.56122726e-01,  5.54970186e-01,  2.54731914e+00,
#        -3.93350915e-01,  1.51082556e-01, -1.83612029e+00, -9.95660567e-01,
#         6.34098078e-01,  5.24625701e-01,  1.86344549e+00, -5.87288262e-01,
#         1.19930612e+00,  6.73509152e-01,  2.86806237e-01,  4.45781431e-01,
#         1.00005379e+00, -1.13896395e+00,  8.91297433e-01, -3.42603342e-01,
#         4.93538003e-01,  2.17834256e+00,  1.16360588e-02, -2.43659522e-01,
#        -5.77346696e-01, -4.46626969e-01,  7.90008451e-01, -3.06627247e-01,
#         4.67254611e-01, -1.46060452e+00, -3.87762966e-01, -6.07668932e-01,
#        -1.30901584e+00, -4.43774695e-01,  6.28627526e-01,  4.45384924e-01,
#         8.97257988e-01, -5.51771812e-01, -2.47315428e-01, -2.05024953e+00,
#        -1.64449544e+00, -1.09701169e+00, -8.22822231e-02, -5.31135257e-01,
#        -1.28267635e+00, -2.54942183e-01, -8.34369061e-01, -2.09529916e+00])

# %%
plt.hist(random_list, 
         bins=50,  
         density=False, # 
         stacked=False, 
         alpha=.5, 
         label='random_list',
         color='b'
        );
plt.legend()

# %%
step_str1 = '1 3 2 4 5 7 1 8'
step_str2 = '100 300 250 400 230 280 320 112'
step_str3 = '15 10 13 7 28 31 20 32'

# %%
step_list1 = function1(function2(step_str1))
step_list2 = function1(function2(step_str2))
step_list3 = function1(function2(step_str3))

# %%
print(f'Стандартное отклонение step_str1 - {np.std(step_list1)}\nСтандартное отклонение step_str2 - {np.std(step_list2)}\nСтандартное отклонение step_str2 - {np.std(step_list3)}')
# Out:
# Стандартное отклонение step_str1 - 2.4717149916606487
# Стандартное отклонение step_str2 - 95.35197952848173
# Стандартное отклонение step_str2 - 9.151502608861563

# %%
norn_list = np.random.randn(100000)

# %%
norn_list_temp = norn_list

# %%
norn_list_temp = norn_list_temp * 2

# %%
plt.hist([norn_list, norn_list_temp], 
         bins=100,  
         density=False, # 
         stacked=False, 
         alpha=1, 
         label=['norn_list', 'norn_list_temp'],
         #color='b'
        );
plt.legend()

# %%
sns.displot([norn_list, norn_list_temp], kind='kde');

# %%
np.var(norn_list_temp)
# Out:
# 4.029341094688117

# %%
np.var(norn_list) * 2 ** 2
# Out:
# 4.029341094688117

# %%
print(f'Дисперсия нормального распределения умноженная на C*2 - {round(np.var(norn_list_temp), 3)}\n\
Дисперсия нормального распределения при С*2 - {round(np.var(norn_list_temp), 3)}')
# Out:
# Дисперсия нормального распределения умноженная на C*2 - 4.029
# Дисперсия нормального распределения при С*2 - 4.029

# %% [markdown]
# Задачи по курсу юнит 1.5

# %% [markdown]
# 1.1 Рассчитайте среднеквадратическое отклонение данных выборочных значений: 1 5 2 7 1 9 3 8 5 9

# %%
step_str4 = '1 5 2 7 1 9 3 8 5 9'

# %%
step_str4 = function1(function2(step_str4))

# %%
step_str4
# Out:
# [1, 5, 2, 7, 1, 9, 3, 8, 5, 9]

# %%
np.std(step_str4, ddof=1)
# Out:
# 3.1622776601683795

# %% [markdown]
# 1.2 Как соотносятся дисперсии  двух выборок
#
# (1) 1 3 5 6 6 7 9 11
#
# (2) 5 7 9 10 10 11 13 15
#
# (Постарайтесь решить данное задание не рассчитывая значения дисперсии, но воспользовавшись одним из свойств)

# %%
# Они равны

# %% [markdown]
# 1.3 Как соотносятся стандартные (среднеквадратические) отклонения двух выборок:
#
# (1) 2 4 5 8 9 10 14 16
#
# (2) 6 12 15 24 27 30 42 48

# %% [markdown]
# Квантили и Квартили

# %%
sns.boxplot(x=step_str4, saturation=0.1)
plt.show()
# показывает в каких пределах лежит 50% всех значений, выбросы и медиану

# %% [markdown]
# Нормальное распределение

# %%
rand_list = 5 * np.random.randn(100000) + 3
rand_list_4 = 2 * np.random.randn(100000) + 3

# %%
sns.displot([rand_list, rand_list_4], kind='kde');

# %%
rand_list_norm = []
for i in rand_list:
    rand_list_norm.append((i - np.mean(rand_list)) / np.std(rand_list))

# %%
np.var(rand_list_norm)
# Out:
# 0.9999999999999999

# %%
sns.displot(rand_list_norm, kind='kde');

# %%
round(np.mean(rand_list_norm), 2)
# Out:
# -0.0

# %% [markdown]
# Задача на нормальное распределение

# %% [markdown]
# 1.7.1 Считается, что значение IQ (уровень интеллекта) у людей имеет нормальное распределение со средним значением равным 100 и стандартным отклонением равным 15 (M = 100, sd = 15).
#
#  Какой приблизительно процент людей обладает IQ > 125?

# %%
sd = 15
z = (125 - 100) / 15
z
# Out:
# 1.6666666666666667

# %% [markdown]
# 1.7.2 Считается, что значение IQ (уровень интеллекта) у людей имеет нормальное распределение со средним значением равным 100 и стандартным отклонением равным 15 (M = 100, sd = 15).
#
# Какой приблизительно процент людей обладает IQ  на промежутке от 70 до 112

# %%
sd = 15
z_1 = (70 - 100) / 15
z_2 = (112 - 100) / 15
print(z_1, z_2)
# Out:
# -2.0 0.8

# %% [markdown]
# # Центральная предельная теорема

# %%
rand_list_4 # набор случайных величин из нормального распределения
print(f' Mean - {np.mean(rand_list_4)} \
         Std - {np.std(rand_list_4)} \
         var - {np.var(rand_list_4)}')
# Out:
#  Mean - 3.0085906028802296          Std - 2.000775302192471          var - 4.003101809863375

# %%
def Selection():
    selection_list = []
    i = 30
    while i != 0:
        selection_list.append(random.choice(rand_list_4))
        i -= 1
    return selection_list

# %%
random_selection_1 = Selection()
random_selection_2 = Selection()
random_selection_3 = Selection()
random_selection_4 = Selection()
random_selection_5 = Selection()
random_selection_6 = Selection()
random_selection_7 = Selection()
random_selection_8 = Selection()
random_selection_9 = Selection()

# %%
plt.figure(figsize=(12,8), dpi= 80)
sns.kdeplot(random_selection_1, shade=True, color="g", label="Cyl=1", alpha=.7)
sns.kdeplot(random_selection_2, shade=True, color="deeppink", label="Cyl=2", alpha=.7)
sns.kdeplot(random_selection_3, shade=True, color="dodgerblue", label="Cyl=3", alpha=.7)
sns.kdeplot(random_selection_4, shade=True, color="orange", label="Cyl=4", alpha=.7)
sns.kdeplot(random_selection_5, shade=True, color="r", label="Cyl=5", alpha=.7)
sns.kdeplot(random_selection_6, shade=True, color="b", label="Cyl=6", alpha=.4)

# Decoration
plt.title('Randomize selections', fontsize=22)
plt.legend()
plt.show()

# %%
generator_ran_sel = [[j * 0 + random.choice(rand_list_4) for j in range(0,100)] for j in range(0,6)]

# %%
plt.figure(figsize=(12,8), dpi= 80)
sns.kdeplot(generator_ran_sel[0], shade=True, color="g", label="Cyl=1", alpha=.7)
sns.kdeplot(generator_ran_sel[1], shade=True, color="deeppink", label="Cyl=2", alpha=.7)
sns.kdeplot(generator_ran_sel[2], shade=True, color="dodgerblue", label="Cyl=3", alpha=.7)
sns.kdeplot(generator_ran_sel[3], shade=True, color="orange", label="Cyl=4", alpha=.7)
sns.kdeplot(generator_ran_sel[4], shade=True, color="r", label="Cyl=5", alpha=.7)
sns.kdeplot(generator_ran_sel[5], shade=True, color="b", label="Cyl=6", alpha=.4)

# Decoration
plt.title('Randomize selections', fontsize=22)
plt.legend()
plt.show()

# %%
variance_list = []
mean_list = []
std_list = []
for i in range(0,len(generator_ran_sel)):
    variance_list.append(np.var(generator_ran_sel[i]))
    mean_list.append(np.mean(generator_ran_sel[i]))
    std_list.append(np.std(generator_ran_sel[i]))

# %%
plt.figure(figsize=(12,8), dpi= 80)
sns.kdeplot(variance_list, shade=True, color="g", label="Cyl=Variance", alpha=.7)
sns.kdeplot(mean_list, shade=True, color="deeppink", label="Cyl=Mean", alpha=.7)
sns.kdeplot(std_list, shade=True, color="dodgerblue", label="Cyl=Std", alpha=.7)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print(np.mean(mean_list))
print(np.mean(std_list))
print(np.mean(variance_list))
# Out:
# 3.0292787073511853
# 2.0197191101399574
# 4.106565479538546

# %%
print(f'Gen population Mean - {np.mean(rand_list_4)}, Mean of mean sampels - {np.mean(mean_list)}\n\
Gen population Std - {np.std(rand_list_4)}, Mean of Std sampels - {np.mean(std_list)}\n\
Gen population var - {np.var(rand_list_4)}, Mean of Var sampels - {np.mean(variance_list)}')
# Out:
# Gen population Mean - 3.0085906028802296, Mean of mean sampels - 3.0292787073511853
# Gen population Std - 2.000775302192471, Mean of Std sampels - 2.0197191101399574
# Gen population var - 4.003101809863375, Mean of Var sampels - 4.106565479538546

# %% [markdown]
# Задачи на ЦПТ
# 1.8.1
# Рассчитайте стандартную ошибку среднего, если выборочное среднее равняется 10, дисперсия 4, при N = 100

# %%
X = 10
D = 4
N = 100
sig = 20
se = D**(1/2) / N ** (1/2)

# %%
se
# Out:
# 0.2

# %% [markdown]
# # Доверительные интервалы

# %%
random_values = [i * 0 + random.randint(80,120) for i in range(0, 100000)]

# %%
rand_sampels = []
for i in range(0,99):
    rand_sampels.append(random.choice(random_values))

# %%
print(f'Gen population Mean - {np.mean(random_values)}, Mean of sampels - {np.mean(rand_sampels)}\n\
Gen population Std - {np.std(random_values)}, Std of sampels - {np.std(rand_sampels)}\n\
Gen population var - {np.var(random_values)}, Var of sampels - {np.var(rand_sampels, ddof=1)}')
# Out:
# Gen population Mean - 99.96218, Mean of sampels - 100.48484848484848
# Gen population Std - 11.857829044458347, Std of sampels - 12.165826983364688
# Gen population var - 140.60810964759997, Var of sampels - 149.51762523191093

# %%
se = np.std(rand_sampels) / 100 ** (1/2)
se
# Out:
# 1.216582698336469

# %%
border_top = np.mean(rand_sampels) + 1.96 * se
border_down = np.mean(rand_sampels) - 1.96 * se
print(f'lower bound - {border_down}\n\
upper top - {border_top}')
# Out:
# lower bound - 98.100346396109
# upper top - 102.86935057358797

# %%
samples_matrix = [[j * 0 + random.choice(random_values) for j in range(0,1000)] for j in range(0,1000)]

# %%
conf_mean = []
for i in range(0,999):
    conf_mean.append(np.mean(samples_matrix[i]))

# %%
excep_list = []
interval_mean = []
for i in conf_mean:
    if i <= border_top and i >= border_down:
        interval_mean.append(i)
    else:
        excep_list.append(i)
        
print(len(excep_list))
print(len(interval_mean))
# Out:
# 0
# 999

# %%
border_top1 = 10 + 2.56 * (5 / 10)
border_down1 = 10 - 2.56 * (5 / 10)
print(f'lower bound - {border_down1}\n\
upper top - {border_top1}')
# Out:
# lower bound - 8.72
# upper top - 11.28

# %% [markdown]
# # Проверка гипотез

# %% [markdown]
# Использование доверительных интервалов зачастую рассматривают, как альтернативный способ проверки гипотез. В нашем случае, если значение 20 (предполагаемое среднее значение в генеральной совокупности) не будет принадлежать 95% доверительному интервалу, рассчитанному по выборочным данным, у нас будет достаточно оснований отклонить нулевую гипотезу. Проверьте согласуются ли результаты двух этих подходов: рассчитайте 95% доверительный интервал для среднего значения, на примере с тестированием нового препарата.
#
# n = 64,  sd = 4,   M = 18.5

# %%
N = 64
sd = 4
X = 18.5
se = 4 / 8

# %%
border_top2 = 18.5 + 1.96 * se
border_down2 = 18.5 - 1.96 * se

# %%
print(f'lower bound - {border_down2}\n\
upper top - {border_top2}')
# Out:
# lower bound - 17.52
# upper top - 19.48

# %% [markdown]
# Данные некоторого исследования сообщают нам, что средний рост детей в 10 лет составляет 136 сантиметров. Однако это лишь выборочная оценка, и исследователи рассчитали 99% доверительный интервал, который составил [130, 142]. Укажите верные утверждения:

# %% [markdown]
# # 2.2 Распределение стьюдента

# %% [markdown]
# Построим график распредления средних по малым выборкам N = 5,6,7,8,9,10

# %%
student_small_sampels_n5 = [[random.choice(random_list) for j in range(0,5)] for j in range(0,1000)]
student_small_sampels_n6 = [[random.choice(random_list) for j in range(0,6)] for j in range(0,1000)] 
student_small_sampels_n7 = [[random.choice(random_list) for j in range(0,7)] for j in range(0,1000)] 
student_small_sampels_n8 = [[random.choice(random_list) for j in range(0,8)] for j in range(0,1000)] 
student_small_sampels_n9 = [[random.choice(random_list) for j in range(0,9)] for j in range(0,1000)] 
student_small_sampels_n10 = [[random.choice(random_list) for j in range(0,10)] for j in range(0,1000)] 

# возьмем 1000 выборок по 5,6,7,8,9,10 элементов

# %%
student_more_sampels = [[random.choice(random_list) for j in range(0,50)] for j in range(0,1000)] 
# возьмем 1000 выборок по 100 элементов

# %%
small_mean_sampels_n5 = [j * 0 + np.mean(student_small_sampels_n5[j]) for j in range(0,1000)] # список со средними выборок
small_mean_sampels_n6 = [j * 0 + np.mean(student_small_sampels_n6[j]) for j in range(0,1000)] # список со средними выборок
small_mean_sampels_n7 = [j * 0 + np.mean(student_small_sampels_n7[j]) for j in range(0,1000)] # список со средними выборок
small_mean_sampels_n8 = [j * 0 + np.mean(student_small_sampels_n8[j]) for j in range(0,1000)] # список со средними выборок
small_mean_sampels_n9 = [j * 0 + np.mean(student_small_sampels_n9[j]) for j in range(0,1000)] # список со средними выборок
small_mean_sampels_n10 = [j * 0 + np.mean(student_small_sampels_n10[j]) for j in range(0,1000)] # список со средними выборок

# %%
more_mean_sampels = [np.mean(student_more_sampels[j]) for j in range(0,1000)] # список со средними выборок

# %%
plt.figure(figsize=(12,8), dpi= 80)
sns.kdeplot(small_mean_sampels_n5, shade=True, color="green", label="Cyl=t-distrib mean", alpha=.5)
sns.kdeplot(small_mean_sampels_n6, shade=True, color="blue", label="Cyl=t-distrib mean", alpha=.5)
sns.kdeplot(small_mean_sampels_n7, shade=True, color="red", label="Cyl=t-distrib mean", alpha=.5)
sns.kdeplot(small_mean_sampels_n8, shade=True, color="orange", label="Cyl=t-distrib mean", alpha=.5)
sns.kdeplot(small_mean_sampels_n9, shade=True, color="deeppink", label="Cyl=t-distrib mean", alpha=.5)
sns.kdeplot(small_mean_sampels_n10, shade=True, color="dodgerblue", label="Cyl=t-distrib mean", alpha=.5)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# 2.2.1 Задача
# Предположим, что мы дали оценить наше пиво 1000 людям по 10-ти бальной шкале и получили следующий резлуьтат:

# %%
gen_pop = np.round(stats.norm.rvs(loc=80, scale=5, size=1000, random_state=True), 0)
# М = 80, std = 5

# %%
print(f'Gen population Mean - {np.mean(gen_pop)}\n\
Gen population Std - {np.std(gen_pop)}\n\
Gen population var - {np.var(gen_pop, ddof=0)}')
# Out:
# Gen population Mean - 80.207
# Gen population Std - 4.920990855508674
# Gen population var - 24.216150999999996

# %%
sns.displot(data=gen_pop) # распределение оценок

# %% [markdown]
# Далее предположим, что мы вынуждены были поменять один из компонентов состава. Сделали пробную партию и дали ее на оценку 10-ти людям. Получили следующие результаты

# %%
est_sample = np.array([89, 99, 93, 84, 79, 61, 82, 81, 87, 82])
print(f'Sample mean - {np.mean(est_sample)}, \n\
Sample std - {np.round(np.std(est_sample, ddof=1), 2)}')
# Out:
# Sample mean - 83.7,
# Sample std - 10.06

# %% [markdown]
# Вычислим Z критерий

# %%
se = np.std(gen_pop) / len(est_sample) ** 0.5
z = (np.mean(est_sample) - np.mean(gen_pop)) / se
print(f'se - {se}\n\
Z - {z}')
# Out:
# se - 1.556153944826796
# Z - 2.244636535872284

# %% [markdown]
#  Вычислим p-value

# %%
1 - (stats.norm.cdf(z) - stats.norm.cdf(-z))
# Out:
# 0.0247914752745495

# %% [markdown]
# Результат получился весьма обнадеживающим. При верности нулевой гипотезы о том, что замена компонента в составе не повлияла на вкус, вероятность отобрать 10 случайных респондетов, которые оценят вкус со средним в 83.7 равен 0,024, что меньше 0,05, а значит 0 гипотезу мы можем смело отклонить. НО. Стандартное отклонение в выборке = 10, против 5 в ген совокупности, выглядит подозрительно. Ниже рассмотрим как степень свободы влияет на график распределния стандартных отклонений

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize = (12, 5))

for i in [0, 1]:
    deviations = np.std(stats.norm.rvs(80, 5, (10000, 10)), axis=1, ddof=i)
    sns.histplot(x=deviations ,stat='probability', ax=ax[i])
    ax[i].vlines(5, 0, 0.06, color='r', lw=2)
    ax[i].set_title('ddof = ' + str(i), fontsize = 15)
    ax[i].set_ylim(0, 0.07)
    ax[i].set_xlim(0, 11)
fig.suptitle(r'$s={\sqrt {{\frac {1}{10 - \mathrm{ddof}}}\sum _{i=1}^{10}\left(x_{i}-{\bar {x}}\right)^{2}}}$',
             fontsize = 20, y=1.15);

# %% [markdown]
# Посмотрим как распределены стандартные отклонения выборок по 10 штук из нашей ГС

# %%
matrix_samp_pop = [np.std([random.choice(gen_pop) for i in range(0,10)]) for j in range(0, 1000)]

# %%
sns.histplot(x=matrix_samp_pop ,stat='probability')
# Out:
# <AxesSubplot:ylabel='Probability'>

# %% [markdown]
# Среднее стандартное отклонение в случайных выборках из 10 очевидно плавает в диапазоне от 4-5. Очевидно, что вероятность отобрать выборку таким образом, чтобы стандартное отклонение было 10 близится к 0. Следовательно, можно выдвинуть гипотезу о том, что после изменения состава нашего пива изменилась не только средняя оценка, но и стандартное отклонение
#
# Рассмотрим новую ГС N(80,10^2) и определим p-value

# %%
new_gen_pop = np.round(stats.norm.rvs(loc=80, scale=10, size=1000, random_state=True), 0)

# %%
# возьмем ту же выборку
est_sample = np.array([89, 99, 93, 84, 79, 61, 82, 81, 87, 82])
print(f'Sample mean - {np.mean(est_sample)}, \n\
Sample std - {np.round(np.std(est_sample, ddof=1), 2)}')
# Out:
# Sample mean - 83.7,
# Sample std - 10.06

# %%
# определим Z критерий
z = (np.mean(est_sample) - np.mean(new_gen_pop)) / ((np.std(new_gen_pop)) / len(est_sample) ** (0.5)) 
z
# Out:
# 1.0664891857853966

# %%
p = (1 - (stats.norm.cdf(z) - stats.norm.cdf(-z)))
print(f'p-values - {np.round(p, 2)}')
# Out:
# p-values - 0.29

# %%
N = 10000
samples = np.round(stats.norm.rvs(80, 5, (N, 10)), 2)
statistic = [lambda x: (np.mean(x, axis=1) - 80) / (np.std(x, axis=1, ddof=1) / 10 ** 0.5),
             lambda x: (np.mean(x, axis=1) - 80) / (np.std(gen_pop) / 10 ** 0.5)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
title = "TZ"

for i in [0, 1]:
    values = statistic[i](samples)
    sns.histplot(x=values ,stat='probability', ax=ax[i])
    p = values[(values > -2)&(values < 2)].size/N
    ax[i].set_title('P(-2 < {} < 2) = {:.3}'.format(title[i], p))
    ax[i].set_xlim(-6, 6)
    ax[i].vlines([-2, 2], 0, 0.06, color='r')

# %%
N = 10000
sigma = np.linspace(5, 20, 151)
prob = []

for i in sigma:
    p = []
    for j in range(10):
        samples = stats.norm.rvs(80, i, (N, 10))
        means = samples.mean(axis=1)
        deviations = samples.std(ddof=1, axis=1)
        p_m = means[(means >= 83) & (means <= 84)].size/N
        p_d = deviations[(deviations >= 9.5) & (deviations <= 10.5)].size/N
        p.append(p_m*p_d)
    prob.append(sum(p)/len(p))
prob = np.array(prob)

fig, ax = plt.subplots()
ax.plot(sigma, prob)
ax.set_xlabel(r'Стандартное отклонение генеральной совокупности ($\sigma$)',
              fontsize=20)
ax.set_ylabel('Вероятность',
              fontsize=20);

# %% [markdown]
# 2.2.2 Задача на t - критерий Стьюдента
# Есть два набора данных температуры денатурации ДНК молекулы. Необходимо выяснить принадлежат ли эти выборке одной ГС или нет.

# %%
denatr1 = [84.7, 105.0, 98.9, 97.9, 108.7, 81.3, 99.4, 89.4, 93.0, 119.3, 99.2, 99.4, 97.1, 112.4, 
                99.8, 94.7, 114.0, 95.1, 115.5, 111.5]
denatr2 = [57.2, 68.6, 104.4, 95.1, 89.9, 70.8, 83.5, 60.1, 75.7, 102.0, 69.0,
               79.6, 68.9, 98.6, 76.0, 74.8, 56.0, 55.6, 69.4, 59.5]

# %%
def statCrits(data): 
    return np.round(np.mean(data), 2), \
           np.round(np.std(data, ddof=1), 2), \
           np.round(np.var(data, ddof=1), 2), \
           np.round(len(data), 2)

# %%
mean1, std1, var1, x1 = statCrits(denatr1)

# %%
mean2, std2, var2, x2 = statCrits(denatr2)

# %% [markdown]
# Сформулируем гипотезу:\
# Н0: М1 = М2 \
# Н1: М1 не равно М2
#
# Для того, чтобы проверить заданную гипотезу, необходимо вычислить t-критерий Стьюдента

# %%
X1 = 89.9
std1 = 11.3
var1 = std1**2
N1 = 20

# %%
X2 = 80.7
std2 = 11.7
var2 = std2**2
N2 = 20

# %%
dof = N2 + N1 - 2
t = (X2 - X1) / (std1**2/N1 + std2**2/N2)**(0.5)
pvalue = 0.0161
print(dof, np.round(t, 2), pvalue)
# Out:
# 38 -2.53 0.0161

# %% [markdown]
# Вывод: p-value ниже 0.05, что дает нам основания не принимать Н0

# %%
stats.ttest_ind(denatr1, denatr2)
# Out:
# Ttest_indResult(statistic=6.04781958789892, pvalue=4.894702897415829e-07)

# %%
X1 = 45
std1 = 9
var1 = std1**2
N1 = 100

X2 = 34
std2 = 10
var2 = std2**2
N2 = 100

# %%
t = (X2 - X1) / (std1**2/N1 + std2**2/N2)**(0.5)
t
# Out:
# -8.176235608718828

# %% [markdown]
# # Корреляция и регрессия

# %% [markdown]
# ## Понятие корреляции

# %%
a = [4,5,2,3,1]
b = [2,1,4,3,5]

plt.plot(a,b,'o', color='black')

# %%
def corr(a,b):
    mean_a = np.mean(a)
    mean_b = np.mean(b)
    desp_a = 0
    desp_b = 0
    
    for i in a:
        desp_a = desp_a + (i - mean_a)
        
    for i in b:
        desp_b = desp_b + (i - mean_b)
        
    r = desp_a * desp_b / desp_a**2 / desp_b**2
    
    return r

# %%
a = [4,5,2,3,1]
b = [2,1,4,3,5]
mean_a = np.mean(a)
mean_b = np.mean(b)
desp_a = []
desp_b = []

# %%
stats.pearsonr(a,b)
# Out:
# (-1.0, 0.0)
